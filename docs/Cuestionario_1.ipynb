# %% [markdown]
# ### Pregunta 1:
# **En el contexto de machine learning no supervisado, ¿qué caracteriza principalmente a los datos utilizados?**
#
# A) Datos etiquetados con categorías claras.
#
# B) Datos sin etiquetas, donde el modelo descubre patrones.
#
# C) Datos con etiquetas parciales utilizadas para entrenamiento supervisado.
#
# D) Datos estructurados específicamente para clasificación.
#
# ### Pregunta 2:
# **¿Cuál es un ejemplo clave de aplicación de modelos no supervisados en el campo de la medicina?**
#
# A) Diagnóstico basado en síntomas definidos.
#
# B) Análisis de imágenes médicas y detección de enfermedades.
#
# C) Prescripción de tratamientos basados en diagnósticos médicos.
#
# D) Estudios genéticos con datos etiquetados.
#
# ### Pregunta 3:
# **¿Qué representa la matriz de distancias en el contexto de los modelos de conglomerados?**
#
# A) Una matriz que define la relación lineal entre variables.
#
# B) Una matriz que muestra la distancia entre pares de objetos.
#
# C) Una matriz utilizada para el cálculo de probabilidades condicionales.
#
# D) Una matriz que describe la correlación entre diferentes características.
#
# ### Pregunta 4:
# **¿Cuál de los siguientes no es un ejemplo de aprendizaje no supervisado?**
#
# A) Clustering.
#
# B) Regresión lineal.
#
# C) Análisis de componentes principales (PCA).
#
# D) Detección de anomalías.
#
# ### Pregunta 5:
# **En el aprendizaje no supervisado, ¿qué se entiende por "representación latente" de los datos?**
#
# A) La categorización explícita de los datos en clases definidas.
#
# B) La relación directa entre características y etiquetas.
#
# C) La representación subyacente o los patrones descubiertos en los datos.
#
# D) La descripción detallada y visible de cada dato.
#
# ### Pregunta 6:
# **¿Cuál es la importancia de la simetría en una matriz de distancias en análisis de conglomerados?**
#
# A) Indica la dirección del flujo de datos en el modelo.
#
# B) Refleja que la distancia entre dos puntos es independiente del orden en que se consideran.
#
# C) Demuestra la relación lineal entre las variables del conjunto de datos.
#
# D) Sirve para calcular la varianza y covarianza entre diferentes grupos.
#
# ### Pregunta 7:
#
# **¿Cuál es la diferencia principal entre los modelos jerárquicos y no jerárquicos en clustering?**
#
#
# A) Los modelos jerárquicos requieren el número de clusters de antemano, mientras que los no jerárquicos lo determinan automáticamente.
#
# B) Los modelos jerárquicos crean una serie de particiones basadas en similitud, mientras que los no jerárquicos
# agrupan los datos en un solo nivel.
#
# C) Los modelos jerárquicos son siempre supervisados, mientras que los no jerárquicos son no supervisados.
#
# D) Los modelos jerárquicos se usan exclusivamente para datos numéricos, mientras que los no jerárquicos se usan para datos categóricos.
