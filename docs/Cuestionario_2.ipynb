# %% [markdown]
# ### Pregunta 1:
# **¿Qué objetivo busca el algoritmo K-Medias en su proceso de agrupación?**
#
# A) Maximizar la distancia entre los clusters.
#
# B) Minimizar la variación dentro de cada cluster.
#
# C) Asignar igual número de puntos a cada cluster.
#
# D) Asegurar que todos los clusters tengan centroides idénticos.
#
# ### Pregunta 2:
# **En el contexto de K-Medias, ¿qué representa un centroide?**
#
# A) El punto más alejado dentro de cada cluster.
#
# B) El promedio de las coordenadas de todos los puntos en un cluster.
#
# C) El punto con la mayor densidad de vecinos en su cluster.
#
# D) La mediana de todas las características en un cluster.
#
# ### Pregunta 3:
# **¿Cuál es una limitación importante del algoritmo K-Medias?**
#
# A) Requiere un número grande de datos para funcionar correctamente.
#
# B) Solo puede aplicarse a datos numéricos.
#
# C) Puede quedar atrapado en óptimos locales.
#
# D) Todos los clusters resultantes tienen siempre el mismo tamaño.
#
# ### Pregunta 4:
# **¿Qué estrategia se utiliza comúnmente para inicializar los centroides en K-Medias?**
#
# A) Inicialización basada en los primeros K puntos del dataset.
#
# B) Inicialización aleatoria de los centroides.
#
# C) Selección de centroides utilizando el método K-means++.
#
# D) Elección de centroides basada en un análisis de componentes principales.
#
# ### Pregunta 5:
# **¿Cómo afecta la elección de 'K' en el resultado del algoritmo K-Medias?**
#
# A) 'K' no tiene ningún efecto significativo en el resultado.
#
# B) Un valor más alto de 'K' siempre resulta en una mejor agrupación.
#
# C) La elección de 'K' determina el número de clusters y puede influir significativamente en la calidad de la
# agrupación.
#
# D) Un valor más bajo de 'K' siempre mejora la eficiencia computacional sin afectar la calidad.
