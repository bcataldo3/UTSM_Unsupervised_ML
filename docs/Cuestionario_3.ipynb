# %% [markdown]
# ### Pregunta 1:
# **¿Qué indica un valor alto en el coeficiente de Silhouette al evaluar un modelo de K-medias?**
#
# A) Una asignación incorrecta de las muestras a los clusters.
#
# B) Que las muestras están más cerca de sus vecinos dentro del mismo grupo que de los grupos más cercanos.
#
# C) Que el número de clusters elegido, 'K', es demasiado alto.
#
# D) Que hay una superposición significativa entre los clusters.
#
# ### Pregunta 2:
# **¿Qué representa el puntaje de Rand ajustado en la evaluación de un modelo de K-medias?**
#
# A) La cohesión interna de los clusters.
#
# B) La correlación entre la asignación de clusters y la verdad fundamental.
#
# C) La distancia media entre los puntos en diferentes clusters.
#
# D) La varianza total explicada por los clusters.
#
# ### Pregunta 3:
# **En el contexto de K-medias, ¿qué sugiere un valor de inercia muy bajo?**
#
# A) Que los puntos dentro de un cluster están muy dispersos.
#
# B) Que los puntos dentro de un cluster están muy cerca de su centroide.
#
# C) Que hay demasiados clusters.
#
# D) Que los clusters son altamente asimétricos.
#
# ### Pregunta 4:
# **¿Qué técnica se utiliza comúnmente para interpretar el coeficiente de Silhouette en K-medias?**
#
# A) Análisis de componentes principales (PCA).
#
# B) Gráficos de representación global y por muestra.
#
# C) Métodos de optimización no lineal.
#
# D) Análisis de varianza (ANOVA).
#
# ### Pregunta 5:
# **Al utilizar el puntaje de Rand ajustado, ¿qué significa un valor cercano a 1?**
#
# A) Que la mayoría de las asignaciones de clusters son incorrectas.
#
# B) Que la asignación de clusters concuerda fuertemente con la verdad fundamental.
#
# C) Que el número de clusters 'K' es subóptimo.
#
# D) Que la distancia entre clusters es mínima.
