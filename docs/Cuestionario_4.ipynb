# %% [markdown]
# ### Pregunta 1:
# **¿Qué caracteriza a los métodos de agrupación jerárquica en comparación con K-means y otros algoritmos de clustering?**
#
# A) Requieren la especificación del número de grupos a priori.
#
# B) Producen representaciones jerárquicas que no requieren una configuración inicial específica.
#
# C) Utilizan centroides para determinar la agrupación.
#
# D) Siempre producen grupos convexos.
#
# ### Pregunta 2:
# **En la agrupación jerárquica, ¿qué describe un enfoque aglomerativo?**
#
# A) Comienza con un único grupo que se divide sucesivamente.
#
# B) Comienza con cada observación como un grupo y los fusiona progresivamente.
#
# C) Utiliza la varianza para dividir los grupos.
#
# D) Se basa en la distancia máxima entre observaciones para fusionar grupos.
#
# ### Pregunta 3:
# **¿Qué representa un dendrograma en el contexto de los conglomerados jerárquicos?**
#
# A) Una representación gráfica de las distancias euclidianas entre cada par de observaciones.
#
# B) Un gráfico que muestra la distribución de los grupos a lo largo de diferentes niveles de similitud.
#
# C) Una representación visual de la varianza interna de cada cluster.
#
# D) Un diagrama que indica la cantidad óptima de clusters.
#
# ### Pregunta 4:
# **¿Qué métrica se utiliza a menudo en el enlace de Ward durante el análisis jerárquico?**
#
# A) Distancia máxima entre los grupos.
#
# B) Distancia media entre los grupos.
#
# C) Incremento mínimo en la suma total de las varianzas cuadráticas dentro del cluster.
#
# D) Distancia euclidiana entre los centroides de los grupos.
#
# ### Pregunta 5:
# **¿Cuál es una limitación de los métodos de agrupación jerárquica?**
#
# A) No pueden aplicarse a datos de alta dimensionalidad.
#
# B) Son particularmente sensibles a los valores atípicos.
#
# C) No pueden manejar grandes volúmenes de datos.
#
# D) Siempre requieren normalización de datos.
