# %% [markdown]
# ### Pregunta 1:
# **¿Cuál es el principal objetivo del Análisis de Componentes Principales (PCA) en la reducción de dimensionalidad?**
#
# A) Maximizar la varianza entre los componentes.
#
# B) Minimizar la pérdida de información al reducir las dimensiones.
#
# C) Alinear los datos a lo largo de ejes ortogonales.
#
# D) Agrupar los datos en componentes separados.
#
# ### Pregunta 2:
# **¿Qué representa un 'componente principal' en PCA?**
#
# A) Una variable original en el conjunto de datos.
#
# B) Una combinación lineal de las variables originales que maximiza la varianza.
#
# C) Un cluster de variables altamente correlacionadas.
#
# D) Una nueva variable con mínima correlación con las demás.
#
# ### Pregunta 3:
# **En el contexto de PCA, ¿qué se entiende por 'whitening' o blanqueamiento de datos?**
#
# A) Eliminar todas las variables con baja varianza.
#
# B) Normalizar los componentes principales para tener varianza unitaria.
#
# C) Convertir todas las variables a una escala común.
#
# D) Seleccionar solo los componentes principales que explican la mayoría de la varianza.
#
# ### Pregunta 4:
# **¿Cómo afecta la 'maldición de la dimensionalidad' al análisis de datos?**
#
# A) Facilita la visualización de los datos en espacios de alta dimensión.
#
# B) Aumenta la eficiencia de los algoritmos de aprendizaje automático.
#
# C) Hace que los datos se vuelvan más dispersos, aumentando los requisitos computacionales y el riesgo de sobreajuste.
#
# D) Mejora la precisión de los modelos al proporcionar más información.
#
# ### Pregunta 5:
# **¿Qué técnica se utiliza comúnmente para determinar el número de componentes principales a retener en PCA?**
#
# A) El método del codo.
#
# B) Análisis de varianza (ANOVA).
#
# C) Prueba de hipótesis estadísticas.
#
# D) Proporción de varianza explicada.
