# %% [markdown]
# ### Pregunta 1:
# **¿Cuál es una característica común de los conjuntos de datos utilizados en la detección de anomalías?**
#
# A) Equilibrio entre las clases de datos.
#
# B) Alta dimensionalidad.
#
# C) Desequilibrio significativo, con muy pocas anomalías.
#
# D) Ausencia de ruido en los datos.
#
# ### Pregunta 2:
# **¿Qué estrategia es típicamente utilizada para identificar anomalías en un conjunto de datos?**
#
# A) Clasificación supervisada.
#
# B) Regresión lineal.
#
# C) Análisis de conglomerados.
#
# D) Estimación de densidad.
#
# ### Pregunta 3:
# **En la estimación de densidad del kernel, ¿qué efecto tiene un ancho de banda muy pequeño?**
#
# A) Reduce el sobreajuste y mejora la generalización.
#
# B) Puede llevar a sobreajuste y detectar falsas anomalías.
#
# C) Garantiza una detección precisa de todas las anomalías.
#
# D) Elimina el ruido de los datos.
#
# ### Pregunta 4:
# **¿Qué papel juega el parámetro 'h' en la estimación de densidad del kernel?**
#
# A) Define el número de componentes principales a retener.
#
# B) Determina el número de clusters en el análisis.
#
# C) Controla el ancho de banda del kernel.
#
# D) Especifica la cantidad de iteraciones en el algoritmo.
#
# ### Pregunta 5:
# **¿Qué implica un valor muy alto en el ancho de banda durante la estimación de densidad del kernel?**
#
# A) Una alta sensibilidad a las anomalías.
#
# B) Una menor distinción entre los datos normales y anómalos.
#
# C) Una detección más precisa de las anomalías.
#
# D) Un aumento en la complejidad computacional del modelo.
#
# ### Pregunta 5:
# **¿Cuál es el objetivo principal al ajustar el ancho de banda en la estimación de densidad del kernel?**
#
# A) Minimizar el error cuadrático medio.
#
# B) Equilibrar la sensibilidad y especificidad en la detección de anomalías.
#
# C) Maximizar la separación entre las clases de datos.
#
# D) Asegurar una distribución uniforme de los datos.
#
# ### Pregunta 7:
# **En el contexto de la detección de anomalías, ¿cómo se define típicamente una 'anomalía'?**
#
# A) Una observación que se ajusta bien al patrón general de los datos.
#
# B) Una observación que difiere significativamente del resto de los datos.
#
# C) Una observación que pertenece a la clase mayoritaria.
#
# D) Una observación con valores faltantes o erróneos.
