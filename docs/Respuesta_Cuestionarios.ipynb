# %% [markdown]
# **Cuestionario sobre "Machoine Learning No Supervisado"**
#
# Pregunta 1: B) Análisis de imágenes médicas y detección de enfermedades.
#
# Pregunta 2: B) Datos sin etiquetas, donde el modelo descubre patrones.
#
# Pregunta 3: B) Una matriz que muestra la distancia entre pares de objetos.
#
# Pregunta 4: B) Regresión lineal.
#
# Pregunta 5: C) La representación subyacente o los patrones descubiertos en los datos.
#
#
# **Cuestionario sobre "Modelos de Conglomerados: K - Medias"**
#
# Pregunta 1: B) Minimizar la variación dentro de cada cluster.
#
# Pregunta 2: B) El promedio de las coordenadas de todos los puntos en un cluster.
#
# Pregunta 3: C) Puede quedar atrapado en óptimos locales.
#
# Pregunta 4: C) Selección de centroides utilizando el método K-means++.
#
#
# Pregunta 5: C) La elección de 'K' determina el número de clusters y puede influir significativamente en la calidad de la agrupación.
#
# **Cuestionario sobre "Modelo K-medias - Métricas de Evaluación"**
#
# Pregunta 1: C) Inercia o suma de cuadrados dentro del cluster.
#
# Pregunta 2: A) Los clusters están bien separados y sus elementos están cercanos a sus respectivos centroides.
#
# Pregunta 3: C) Determinar la suma de las distancias al cuadrado de cada punto a su centroide más cercano.
#
# Pregunta 4: B) La inercia disminuye a medida que 'K' aumenta.
#
# Pregunta 5: C) Método del codo.
#
# **Cuestionario sobre "Modelos de Conglomerados: Conglomerados Jerárquicos"**
#
# Pregunta 1: ) Los métodos jerárquicos no requieren la especificación del número de clusters a priori.
#
# Pregunta 2: ) Los aglomerativos comienzan con cada punto como un cluster individual y los fusionan, mientras que los divisivos comienzan con un único cluster y lo dividen.
#
# Pregunta 3: ) Un diagrama que muestra la formación de clusters y sus niveles de similitud.
#
# Pregunta 4: ) Distancia euclidiana, Manhattan u otras métricas de distancia.
#
# Pregunta 5: ) Puede ser difícil visualizar y analizar claramente debido a la gran cantidad de ramas y niveles.
#
# **Cuestionario sobre "Reducción de Dimensionalidad y Análisis de Componentes Principales"**
#
# Pregunta 1: B) Minimizar la pérdida de información al reducir las dimensiones.
#
# Pregunta 2: B) Una combinación lineal de las variables originales que maximiza la varianza.
#
# Pregunta 3: B) Normalizar los componentes principales para tener varianza unitaria.
#
# Pregunta 4: C) Hace que los datos se vuelvan más dispersos, aumentando los requisitos computacionales y el riesgo de sobreajuste.
#
# Pregunta 5: A) El método del codo.
#
# **Cuestionario sobre "Detección de Anomalías"**
#
# Pregunta 1: C) Desequilibrio significativo, con muy pocas anomalías.
#
# Pregunta 2: D) Estimación de densidad.
#
# Pregunta 3: B) Puede llevar a sobreajuste y detectar falsas anomalías.
#
# Pregunta 4: C) Controla el ancho de banda del kernel.
#
# Pregunta 5: B) Una menor distinción entre los datos normales y anómalos.
#
# Pregunta 6: B) Equilibrar la sensibilidad y especificidad en la detección de anomalías.
#
# Pregunta 7: B) Una observación que difiere significativamente del resto de los datos.
